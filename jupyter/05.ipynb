# %% [markdown]
# #### 코드 5-1 최소제곱법 구현

# %%
data = [[0, 1.5], [2, 1.7], [3, 2.1], [5, 2.2], [6, 2.8], [7, 2.9], [9, 3.2], [11, 3.7]]

def dEa(a, b):
    sum_value = 0
    for i in data:
        sum_value += i[0] * (a * i[0] + b - i[1])

    return sum_value

def dEb(a, b):
    sum_value = 0
    for i in data:
        sum_value += a * i[0] + b - i[1]

    return sum_value

eta = 0.006   # 학습률 설정
a, b = 2, 1   # 경사하강법을 시작하는 기울기값과 절편

# 오차 제곱의 합이 최소일 때의 a, b 계산
for i in range(0, 200):
    a += - eta * dEa(a, b)
    b += - eta * dEb(a, b)
    print([a, b])
# Out:
# [-1.3942000000000005, 1.4323036]
# [1.7187556712000003, 1.0407140640303998]
# [-1.1375221161598432, 1.4048404949261801]
# [1.4819971626608965, 1.0756528832032122]
# [-0.9216157483942804, 1.3823984078951823]
# [1.2826761717376094, 1.1057128320079104]
# [-0.7400162738087701, 1.3641628147141933]
# [1.1148614539220698, 1.131648744496018]
# [-0.5872837573059388, 1.3494488141451413]
# [0.9735617753911956, 1.154096333015246]
# [-0.45884054053956924, 1.337680568489723]
# [0.8545769268422423, 1.1735910540769179]
# [-0.350834572451975, 1.3283740031738354]
# [0.7543723510105269, 1.1905839844607753]
# [-0.26002440145088057, 1.3211222487809853]
# [0.6699736411928423, 1.2054551814117447]
# [-0.1836823959374303, 1.3155833908558379]
# [0.5988777612997528, 1.2185249256794215]
# [-0.11951330406005589, 1.3114701616943036]
# [0.5389783371399228, 1.230063182950877]
# [-0.0655857214842529, 1.3085412663121723]
# [0.48850278870149977, 1.240297566044201]
# [-0.02027442130582857, 1.3065940835709833]
# [0.4459594266792235, 1.2494200354763365]
# [0.017788175501842862, 1.305458524493997]
# [0.4100929339537981, 1.2575925383582052]
# [0.04975283784747492, 1.3049918643523628]
# [0.37984690304198926, 1.2649517538786161]
# [0.0765878896094273, 1.3050743941732104]
# [0.3543323111743558, 1.2716130869699125]
# [0.09910812794612456, 1.3056057617852566]
# [0.33280099191058554, 1.277674029306633]
# [0.11799915812383238, 1.306501893103966]
# [0.314623311361536, 1.2832169879036994]
# [0.13383787132738634, 1.307692401681856]
# [0.29926938260506414, 1.2883116656890203]
# [0.1471096767774218, 1.3091184091273724]
# [0.2862932575065872, 1.293017065052559]
# [0.158223002585182, 1.3107307112630593]
# [0.2753196240382078, 1.2973831741205748]
# [0.1675214982405943, 1.312488235216714]
# [0.2660326119855232, 1.3014523860340468]
# [0.17529430301696886, 1.3143567413260346]
# [0.25816637287176264, 1.3052606935414701]
# [0.18178468683812626, 1.316307731047243]
# [0.2514971528935914, 1.308838694510429]
# [0.18719732156739755, 1.3183175282095398]
# [0.24583662223291106, 1.312212438319391]
# [0.19170439979233164, 1.3203665061336387]
# [0.24102626161480614, 1.315404138342604]
# [0.19545078377354233, 1.3224384374885851]
# [0.23693263854307983, 1.3184327717450184]
# [0.19855833827385944, 1.3245199474266018]
# [0.2334434322037703, 1.3213145844415521]
# [0.20112957662049777, 1.3266000536202691]
# [0.2304640883764977, 1.3240635162453598]
# [0.20325072885102438, 1.3286697794220181]
# [0.22791500450064617, 1.3266915588485946]
# [0.20499432354144878, 1.3307218285501683]
# [0.20879033044565473, 1.3826999070288115]
# [0.2087126100631946, 1.3830824580951244]
# [0.20868774625142306, 1.3834530615736913]
# [0.20861575117513578, 1.383824450814969]
# [0.20858832807335898, 1.3841850885329239]
# [0.20852133548881466, 1.3845456997272294]
# [0.20849194075600092, 1.3848965854252742]
# [0.2084293372420784, 1.3852467803164048]
# [0.20839846029839307, 1.385588132104232]
# [0.2083397246336347, 1.3859282528077512]
# [0.2083077723736472, 1.3862602914005782]
# [0.208252461063686, 1.3865906624589195]
# [0.20821977107509707, 1.3869136097235164]
# [0.20816750616999058, 1.38723453986493]
# [0.20813435785335704, 1.3875486176252472]
# [0.20808481669199705, 1.3878604012727]
# [0.20805144061424624, 1.388165830333135]
# [0.20800434719051727, 1.3884687489019911]
# [0.20797093295229488, 1.3887657482530034]
# [0.20792605064604502, 1.3890600712701795]
# [0.2078927534985509, 1.3893488574465847]
# [0.20784987895515786, 1.3896348435187178]
# [0.20781682536477086, 1.3899156300857085]
# [0.2077757833413549, 1.390193527739525]
# [0.20774307566891542, 1.3904665248854475]
# [0.2077037146940849, 1.3907365732998722]
# [0.20767143512925232, 1.3910019875181312]
# [0.20763362384753248, 1.3912644171645976]
# [0.20760183771637797, 1.3915224510098714]
# [0.20756546180889413, 1.3917774842147028]
# [0.20753422035415728, 1.3920283361210246]
# [0.20749917994432626, 1.3922761875615792]
# [0.2074685226620026, 1.3925200517118268]
# [0.20743473012944622, 1.392760928856262]
# [0.2074046867321105, 1.3929979950942768]
# [0.20737206487017165, 1.3932320985932471]
# [0.20734265693627918, 1.3934625523712112]
# [0.2073111373987623, 1.3936900764085123]
# [0.20728237975777963, 1.3939140987633964]
# [0.20725190174915303, 1.3941352313714719]
# [0.20722380364446485, 1.3943529989253693]
# [0.2071943128150131, 1.3945679222706782]
# [0.20716687887990262, 1.3947796072506706]
# [0.20713832639341948, 1.3949884978931362]
# [0.2071115574698224, 1.3951942681670515]
# [0.20708389921656947, 1.395397297297158]
# [0.20705779304159222, 1.3955973164221636]
# [0.20703098897356922, 1.3957946500787188]
# [0.20700554075479977, 1.395989077360202]
# [0.20697955432400816, 1.3961808766313182]
# [0.20695475722131218, 1.3963698671899163]
# [0.20692955490475504, 1.3965562883993734]
# [0.2069054004334444, 1.396739993244375]
# [0.20688095133117912, 1.3969211881252006]
# [0.2068574296990781, 1.3970997542328287]
# [0.206833705193806, 1.397275870089651]
# [0.20681080558275433, 1.397449440484997]
# [0.20678777905125414, 1.3976206203464936]
# [0.20676548985191326, 1.3977893341880683]
# [0.20674313642016082, 1.3979557169506396]
# [0.20672144542758225, 1.3981197096166926]
# [0.20669974176269015, 1.3982814301803173]
# [0.20667863633892253, 1.39844083335622]
# [0.20665756047211886, 1.3985980227533148]
# [0.20663702768113193, 1.3987529645194237]

# %% [markdown]
# #### 코드 5-2 로지스틱 회귀로 손실함수가 최솟값일 확률 계산

# %%
import numpy as np

data = [[0, 0], [2, 0], [3, 0], [5, 0], [6, 1], [7, 1], [9, 1], [11, 1]]

def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

def dEa(a, b):
    sum_value = 0
    for i in data:
        sum_value += i[0] * (sigmoid(a * i[0] + b) - i[1])

    return sum_value

def dEb(a, b):
    sum_value = 0
    for i in data:
        sum_value += sigmoid(a * i[0] + b) - i[1]

    return sum_value

eta = 0.5     # 학습률 설정
a, b = 2, 1   # 경사하강법을 시작하는 기울기값과 절편

# 최솟값으로 이동했을 때의 결정 경계 계산
for i in range(0, 200):
    a += - eta * dEa(a, b)
    b += - eta * dEb(a, b)
    print([-(b/a)])
# Out:
# [0.8793427752672711]
# [-0.04932468721970782]
# [0.13759368177537623]
# [0.8015969222893439]
# [-0.5381775037301996]
# [0.16494546594290926]
# [0.40230431270027384]
# [1.1119677347331387]
# [-121.81854369666472]
# [0.3156464406782909]
# [0.5964413671630993]
# [1.3464717610574841]
# [7.125090309082412]
# [1.5496233162964095]
# [10.96129036719981]
# [0.6400208165113088]
# [1.2447395964262138]
# [3.7036585113474123]
# [54.496284808117]
# [0.5878475803137864]
# [0.9694500854047747]
# [1.9172483568595653]
# [6.149876475981182]
# [3.220949788116703]
# [10.121294019556927]
# [1.0204467978168437]
# [1.8986833215088534]
# [5.158392074870415]
# [6.576846567511107]
# [2.742288734541904]
# [8.217738199947918]
# [1.7235610769735321]
# [4.120313119786962]
# [10.334499986347387]
# [1.1413327638262802]
# [2.006215050885369]
# [4.542461997115648]
# [9.46410980645903]
# [1.4601996620610764]
# [2.7290361956655578]
# [6.328541613952198]
# [3.3868112385943294]
# [6.599237062839191]
# [3.026877015326864]
# [6.32050734702618]
# [3.4222442385164484]
# [6.575550054883423]
# [3.0768219695583037]
# [6.223201839398019]
# [3.6079580110158123]
# [6.920369781776004]
# [2.7127810454433448]
# [6.023670772144446]
# [4.037646518044073]
# [8.123674337421981]
# [2.114774702190566]
# [4.142460983711635]
# [8.19586000200459]
# [2.137860931403385]
# [4.0776775713175315]
# [7.812253435734559]
# [2.305178014895808]
# [4.426177471206824]
# [8.384605048807028]
# [2.1523887923930363]
# [3.9305453682084615]
# [7.074289933267454]
# [2.7597368729196052]
# [5.472821335189391]
# [5.464245063113048]
# [5.482508176729608]
# [5.443974361523905]
# [5.525516142220858]
# [5.353408722678766]
# [5.718888263217031]
# [4.93691060466701]
# [6.977710180996745]
# [2.8775778244054293]
# [5.498269815592408]
# [5.415526993144627]
# [5.58437303948165]
# [5.238935766263445]
# [5.968507041022573]
# [4.370009286831086]
# [7.970019172234379]
# [2.396867615550761]
# [4.3790034264934095]
# [7.875588473459273]
# [2.4566367620534693]
# [4.483758053558256]
# [7.893940856962761]
# [2.484794582179543]
# [4.497559700016481]
# [7.812396663303384]
# [2.5375474334457104]
# [4.581404651995779]
# [7.735908506306925]
# [2.587711864659044]
# [4.654271635918687]
# [7.597892908225435]
# [2.6554282019978936]
# [4.763531798327983]
# [7.307639188185617]
# [2.8080736692521535]
# [4.981875104110312]
# [6.550897342478092]
# [3.5899702423019724]
# [5.639039136931439]
# [5.221353318302671]
# [5.884262534573826]
# [4.73005675761803]
# [7.335619354145312]
# [2.8224919370423294]
# [4.9339353443845875]
# [6.679965927863132]
# [3.467749288102269]
# [5.3396171985088685]
# [5.6677533784352825]
# [5.1871096191478925]
# [5.932643250753653]
# [4.64527946812502]
# [7.405023382661889]
# [2.819067433622347]
# [4.8674745839609646]
# [6.861528520359315]
# [3.2841239523958237]
# [4.998212321303685]
# [6.420128830670689]
# [3.828748819730153]
# [5.982820717471591]
# [4.561151937741177]
# [7.340800827849781]
# [2.8867657232500687]
# [4.845344082147256]
# [6.885428510157332]
# [3.2957597755136]
# [4.954189570578324]
# [6.529540929888265]
# [3.7387700614627772]
# [5.732780458378361]
# [5.113043155595082]
# [6.04410742023618]
# [4.457375843321927]
# [7.153742119475043]
# [3.044025434333743]
# [4.768077140145425]
# [7.043483401929623]
# [3.157209364211707]
# [4.764281149076921]
# [7.033372742548492]
# [3.1794074939229118]
# [4.759313079866213]
# [7.02674774827626]
# [3.197551195347633]
# [4.755949270298117]
# [7.0176590056254415]
# [3.217861498486536]
# [4.758330436546248]
# [6.9987743874370105]
# [3.2485577616170462]
# [4.776371285833656]
# [6.9505381521831575]
# [3.3137231519394224]
# [4.846962161687962]
# [6.7706629575444195]
# [3.550820156658169]
# [5.217438734396224]
# [5.771674154342145]
# [5.094065787706573]
# [6.020400750597322]
# [4.572390799437957]
# [7.073894334127759]
# [3.1947959507151893]
# [4.683435358845271]
# [7.0454459306771575]
# [3.2342216554769903]
# [4.707595758673112]
# [7.008537828192237]
# [3.2841568900281395]
# [4.755732599253044]
# [6.931102156312198]
# [3.386111070756536]
# [4.893697810053955]
# [6.591439696139499]
# [3.8170773353866334]
# [5.664180594865412]
# [5.29090554464057]
# [5.648466566937508]
# [5.312557213118226]
# [5.624498578242605]
# [5.343244054538999]
# [5.594028006288152]
# [5.378613997568591]
# [5.562742491196278]
# [5.411129569060366]
# [5.536391199787828]
# [5.435947619318161]
# [5.517115685467487]
# [5.452864098059555]
# [5.50412023012486]

# %% [markdown]
# #### 코드 5-3 순전파와 역전파 계산

# %%
import numpy as np

# 가중치 초깃값 설정
V = np.array([[0.1, 0.3], [0.2, 0.4]])
W = np.array([[0.1, 0.3], [0.2, 0.4]])

# 지도 데이터
t = np.array([[1, 0]])

# 학습률
eta = 0.005

# 순전파
x = np.array([[1, 0.5]])
y = x.dot(V)
z = y.dot(W)

# 역전파
delta2 = z - t
grad_W = y.T.dot(delta2)
delta1 = delta2.dot(W.T)
grad_V = x.T.dot(delta1)
W -= eta * grad_W
V -= eta * grad_V
print(V)
print(W)
# Out:
# [[0.10005  0.30036 ]
#  [0.200025 0.40018 ]]
# [[0.10088 0.29974]
#  [0.2022  0.39935]]

# %% [markdown]
# #### 코드 5-4 활성화 함수를 추가한 순전파와 역전파 계산

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def softmax(x):
    e = np.exp(x)
    return e / np.sum(e)

# 가중치 초깃값 설정
V = np.array([[0.1, 0.3], [0.2, 0.4]])
W = np.array([[0.1, 0.3], [0.2, 0.4]])

# 지도 데이터
t = np.array([[1, 0]])

# 학습률
eta = 0.005

# 순전파
x = np.array([[1, 0.5]])
y = sigmoid(x.dot(V))
z = softmax(y.dot(W))

# 역전파
delta2 = z - t
grad_W = y.T.dot(delta2)
sigmoid_dash = y * (1 - y)
delta1 = delta2.dot(W.T) * sigmoid_dash
grad_V = x.T.dot(delta1)
W -= eta * grad_W
V -= eta * grad_V
print(V)
print(W)
# Out:
# [[0.0998618  0.29986879]
#  [0.1999309  0.39993439]]
# [[0.10153499 0.29846501]
#  [0.20173774 0.39826226]]
